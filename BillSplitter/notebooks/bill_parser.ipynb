# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
from langchain_core.messages import HumanMessage
from langchain_core.output_parsers import JsonOutputParser
from pydantic import BaseModel, Field
from typing import List, Optional

load_dotenv()
# Out:
# True

# %%
class LineItem(BaseModel):
    description: str = Field(description="Description of the charge")
    amount: float = Field(description="Amount of the charge")
    category: str = Field(description="Category of the charge (e.g., Plan, Device, Usage, Tax)")

class UserCharge(BaseModel):
    name: str = Field(description="Name of the user or line owner")
    phone_number: Optional[str] = Field(description="Phone number associated with the line")
    items: List[LineItem] = Field(description="List of charges for this user")
    total: float = Field(description="Total charges for this user")

class BillData(BaseModel):
    total_amount: float = Field(description="Total amount of the bill")
    period_start: str = Field(description="Billing period start date")
    period_end: str = Field(description="Billing period end date")
    shared_costs: List[LineItem] = Field(description="Shared costs not specific to a user (e.g., account level taxes, base plan)")
    user_charges: List[UserCharge] = Field(description="Charges broken down by user/line")

# %%
class BillParserAgent:
    def __init__(self, model_name="gemini-2.0-flash"):
        self.llm = ChatGoogleGenerativeAI(model=model_name, temperature=0)
        self.parser = JsonOutputParser(pydantic_object=BillData)

    def parse_bill(self, file_path: str) -> dict:
        """Parses a bill file (image or PDF) and returns structured data."""
        
        # TODO: Handle PDF to image conversion if needed, or pass PDF directly if supported
        # For now assuming image path or text content if we extract it first.
        # Gemini 1.5 Pro can handle PDF directly via API but LangChain integration might need specific handling.
        # Let's assume we pass the file as a media block.
        
        import mimetypes
        mime_type, _ = mimetypes.guess_type(file_path)
        
        if not mime_type:
            raise ValueError("Could not determine mime type of the file")

        with open(file_path, "rb") as f:
            image_data = f.read()

        message = HumanMessage(
            content=[
                {"type": "text", "text": "Extract the following information from this bill. Return JSON matching the specified format. Make sure to extract only information associated with phone number & name and total amount should be the total of all charges."},
                {"type": "text", "text": self.parser.get_format_instructions()},
                {"type": "media", "mime_type": mime_type, "data": image_data},
            ]
        )

        response = self.llm.invoke([message])
        json_result = self.parser.parse(response.content)
        return BillData(**json_result)

# %%
PATH_TO_BILL = "/Users/anandrajravi/Documents/ATT-Bills/ATTBill_1359_Aug2025.pdf"

# %%
bill_parser_agent = BillParserAgent()
result = bill_parser_agent.parse_bill(PATH_TO_BILL)

# %%
result["user_charges"]
# Out:
# [{'name': 'SRAVYA REKAPALLI',
#   'phone_number': '469.882.5794',
#   'items': [{'description': 'Unlimited Extra EL - 5+ Lines',
#     'amount': 35.99,
#     'category': 'Plan'},
#    {'description': 'AutoPay & paperless disc ($10 off w/ bank acct)',
#     'amount': -7.2,
#     'category': 'Plan'},
#    {'description': 'Administrative & Regulatory Cost Recovery Fee',
#     'amount': 3.49,
#     'category': 'Usage'},
#    {'description': 'Federal Universal Service Charge',
#     'amount': 0.53,
#     'category': 'Usage'},
#    {'description': 'TX State Cost Recovery Charge',
#     'amount': 0.11,
#     'category': 'Usage'},
#    {'description': 'Texas Universal Service',
#     'amount': 0.35,
#     'category': 'Usage'},
#    {'description': '9-1-1 Service Fee', 'amount': 0.5, 'category': 'Tax'},
#    {'description': '911 Equalization Surcharge',
#     'amount': 0.06,
#     'category': 'Tax'},
#    {'description': 'City Sales Tax - Telecom',
#     'amount': 0.09,
#     'category': 'Tax'},
#    {'description': 'TX State Sales Tax - Telecom',
#     'amount': 0.32,
#     'category': 'Tax'}],
#   'total': 34.24},
#  {'name': 'NEW LINE',
#   'phone_number': '669.288.3455',
#   'items': [{'description': 'Unlimited Starter SL - 5+ Lines',
#     'amount': 30.99,
#     'category': 'Plan'},
#    {'description': 'AutoPay & paperless disc ($10 off w/ bank acct)',
#     'amount': -6.2,
#     'category': 'Plan'},
#    {'description': 'Discount for bundled eligible wireless with internet',
#     'amount': None,
#     'category': 'Plan'},
#    {'description': 'Administrative & Regulatory Cost Recovery Fee',
#     'amount': 3.49,
#     'category': 'Usage'},
#    {'description': 'Federal Universal Service Charge',
#     'amount': 0.51,
#     'category': 'Usage'},
#    {'description': 'TX State Cost Recovery Charge',
#     'amount': 0.1,
#     'category': 'Usage'},
#    {'description': 'Texas Universal Service',
#     'amount': 0.34,
#     'category': 'Usage'},
#    {'description': '9-1-1 Service Fee', 'amount': 0.5, 'category': 'Tax'},
#    {'description': '911 Equalization Surcharge',
#     'amount': 0.06,
#     'category': 'Tax'},
#    {'description': 'City Sales Tax - Telecom',
#     'amount': 0.08,
#     'category': 'Tax'},
#    {'description': 'TX State Sales Tax - Telecom',
#     'amount': 0.32,
#     'category': 'Tax'}],
#   'total': 30.19},
#  {'name': 'NITHIN ROY',
#   'phone_number': '704.605.2812',
#   'items': [{'description': 'Switcher Promo 12 of 36',
#     'amount': -5.56,
#     'category': 'Usage'},
#    {'description': 'Unlimited Starter SL - 5+ Lines',
#     'amount': 30.99,
#     'category': 'Plan'},
#    {'description': 'AutoPay & paperless disc ($10 off w/ bank acct)',
#     'amount': None,
#     'category': 'Plan'},
#    {'description': 'Discount for bundled eligible wireless with internet',
#     'amount': -6.2,
#     'category': 'Plan'},
#    {'description': 'APPLE128GB - Installment 12 of 36',
#     'amount': 27.78,
#     'category': 'Device'},
#    {'description': 'Administrative & Regulatory Cost Recovery Fee',
#     'amount': 3.49,
#     'category': 'Usage'},
#    {'description': 'Federal Universal Service Charge',
#     'amount': 0.51,
#     'category': 'Usage'},
#    {'description': 'TX State Cost Recovery Charge',
#     'amount': 0.1,
#     'category': 'Usage'},
#    {'description': 'Texas Universal Service',
#     'amount': 0.34,
#     'category': 'Usage'},
#    {'description': '9-1-1 Service Fee', 'amount': 0.5, 'category': 'Tax'},
#    {'description': '911 Equalization Surcharge',
#     'amount': 0.06,
#     'category': 'Tax'},
#    {'description': 'City Sales Tax - Telecom',
#     'amount': 0.08,
#     'category': 'Tax'},
#    {'description': 'TX State Sales Tax - Telecom',
#     'amount': 0.32,
#     'category': 'Tax'}],
#   'total': 52.41},
#  {'name': 'POOVALINGAM JEGANATHAN',
#   'phone_number': '704.713.0646',
#   'items': [{'description': 'Switcher Promo 12 of 36',
#     'amount': -5.56,
#     'category': 'Usage'},
#    {'description': 'Unlimited Starter SL - 5+ Lines',
#     'amount': 30.99,
#     'category': 'Plan'},
#    {'description': 'AutoPay & paperless disc ($10 off w/ bank acct)',
#     'amount': None,
#     'category': 'Plan'},
#    {'description': 'Discount for bundled eligible wireless with internet',
#     'amount': -6.2,
#     'category': 'Plan'},
#    {'description': 'APPLE128GB - Installment 12 of 36',
#     'amount': 20.28,
#     'category': 'Device'},
#    {'description': 'Promotional Credit 12 of 36',
#     'amount': -9.29,
#     'category': 'Usage'},
#    {'description': 'Administrative & Regulatory Cost Recovery Fee',
#     'amount': 3.49,
#     'category': 'Usage'},
#    {'description': 'Federal Universal Service Charge',
#     'amount': 0.51,
#     'category': 'Usage'},
#    {'description': 'TX State Cost Recovery Charge',
#     'amount': 0.1,
#     'category': 'Usage'},
#    {'description': 'Texas Universal Service',
#     'amount': 0.34,
#     'category': 'Usage'},
#    {'description': '9-1-1 Service Fee', 'amount': 0.5, 'category': 'Tax'},
#    {'description': '911 Equalization Surcharge',
#     'amount': 0.06,
#     'category': 'Tax'},
#    {'description': 'City Sales Tax - Telecom',
#     'amount': 0.08,
#     'category': 'Tax'},
#    {'description': 'TX State Sales Tax - Telecom',
#     'amount': 0.32,
#     'category': 'Tax'}],
#   'total': 35.62},
#  {'name': 'ANANDRAJ RAVI',
#   'phone_number': '704.779.5746',
#   'items': [{'description': 'Promotional Credit with Trade In 10 of 36',
#     'amount': -34.73,
#     'category': 'Usage'},
#    {'description': 'Unlimited Extra EL - 5+ Lines',
#     'amount': 35.99,
#     'category': 'Plan'},
#    {'description': 'AutoPay & paperless disc ($10 off w/ bank acct)',
#     'amount': None,
#     'category': 'Plan'},
#    {'description': 'Discount for bundled eligible wireless with internet',
#     'amount': -7.2,
#     'category': 'Plan'},
#    {'description': 'GOOGLE PIXEL 9 PRO XL - 256GB - HAZEL - Installment 10 of 36',
#     'amount': 34.73,
#     'category': 'Device'},
#    {'description': 'Administrative & Regulatory Cost Recovery Fee',
#     'amount': 3.49,
#     'category': 'Usage'},
#    {'description': 'Federal Universal Service Charge',
#     'amount': 0.53,
#     'category': 'Usage'},
#    {'description': 'TX State Cost Recovery Charge',
#     'amount': 0.11,
#     'category': 'Usage'},
#    {'description': 'Texas Universal Service',
#     'amount': 0.35,
#     'category': 'Usage'},
#    {'description': '9-1-1 Service Fee', 'amount': 0.5, 'category': 'Tax'},
#    {'description': '911 Equalization Surcharge',
#     'amount': 0.06,
#     'category': 'Tax'},
#    {'description': 'City Sales Tax - Telecom',
#     'amount': 0.09,
#     'category': 'Tax'},
#    {'description': 'TX State Sales Tax - Telecom',
#     'amount': 0.32,
#     'category': 'Tax'}],
#   'total': 34.24},
#  {'name': 'VIVEK RAVI',
#   'phone_number': '704.907.6585',
#   'items': [{'description': 'Unlimited Extra EL - 5+ Lines',
#     'amount': 35.99,
#     'category': 'Plan'},
#    {'description': 'AutoPay & paperless disc ($10 off w/ bank acct)',
#     'amount': None,
#     'category': 'Plan'},
#    {'description': 'Discount for bundled eligible wireless with internet',
#     'amount': -7.2,
#     'category': 'Plan'},
#    {'description': 'Administrative & Regulatory Cost Recovery Fee',
#     'amount': 3.49,
#     'category': 'Usage'},
#    {'description': 'Federal Universal Service Charge',
#     'amount': 0.53,
#     'category': 'Usage'},
#    {'description': 'TX State Cost Recovery Charge',
#     'amount': 0.11,
#     'category': 'Usage'},
#    {'description': 'Texas Universal Service',
#     'amount': 0.35,
#     'category': 'Usage'},
#    {'description': '9-1-1 Service Fee', 'amount': 0.5, 'category': 'Tax'},
#    {'description': '911 Equalization Surcharge',
#     'amount': 0.06,
#     'category': 'Tax'},
#    {'description': 'City Sales Tax - Telecom',
#     'amount': 0.09,
#     'category': 'Tax'},
#    {'description': 'TX State Sales Tax - Telecom',
#     'amount': 0.32,
#     'category': 'Tax'}],
#   'total': 34.24},
#  {'name': 'PRASANNA KUMAR',
#   'phone_number': '704.907.9228',
#   'items': [{'description': 'Unlimited Extra EL - 5+ Lines',
#     'amount': 35.99,
#     'category': 'Plan'},
#    {'description': 'AutoPay & paperless disc ($10 off w/ bank acct)',
#     'amount': None,
#     'category': 'Plan'},
#    {'description': 'Discount for switching to AT&T with own device',
#     'amount': -10.0,
#     'category': 'Plan'},
#    {'description': 'Discount for bundled eligible wireless with internet',
#     'amount': -5.2,
#     'category': 'Plan'},
#    {'description': 'Administrative & Regulatory Cost Recovery Fee',
#     'amount': 3.49,
#     'category': 'Usage'},
#    {'description': 'Federal Universal Service Charge',
#     'amount': 0.5,
#     'category': 'Usage'},
#    {'description': 'TX State Cost Recovery Charge',
#     'amount': 0.08,
#     'category': 'Usage'},
#    {'description': 'Texas Universal Service',
#     'amount': 0.34,
#     'category': 'Usage'},
#    {'description': '9-1-1 Service Fee', 'amount': 0.5, 'category': 'Tax'},
#    {'description': '911 Equalization Surcharge',
#     'amount': 0.06,
#     'category': 'Tax'},
#    {'description': 'City Sales Tax - Telecom',
#     'amount': 0.08,
#     'category': 'Tax'},
#    {'description': 'TX State Sales Tax - Telecom',
#     'amount': 0.31,
#     'category': 'Tax'}],
#   'total': 26.15},
#  {'name': 'SRIPRIYA PULLELA',
#   'phone_number': '972.922.0727',
#   'items': [{'description': 'International Day Pass',
#     'amount': 12.0,
#     'category': 'Usage'},
#    {'description': 'Smartphone trade-in promo 12 of 36',
#     'amount': -27.78,
#     'category': 'Usage'},
#    {'description': 'Unlimited Extra EL - 5+ Lines',
#     'amount': 35.99,
#     'category': 'Plan'},
#    {'description': 'AutoPay & paperless disc ($10 off w/ bank acct)',
#     'amount': None,
#     'category': 'Plan'},
#    {'description': 'Discount for bundled eligible wireless with internet',
#     'amount': -7.2,
#     'category': 'Plan'},
#    {'description': 'APPLE 512GB - Installment 12 of 36',
#     'amount': 36.12,
#     'category': 'Device'},
#    {'description': 'Administrative & Regulatory Cost Recovery Fee',
#     'amount': 3.49,
#     'category': 'Usage'},
#    {'description': 'Federal Universal Service Charge',
#     'amount': 0.88,
#     'category': 'Usage'},
#    {'description': 'TX State Cost Recovery Charge',
#     'amount': 0.15,
#     'category': 'Usage'},
#    {'description': 'Texas Universal Service',
#     'amount': 0.35,
#     'category': 'Usage'},
#    {'description': '9-1-1 Service Fee', 'amount': 0.5, 'category': 'Tax'},
#    {'description': '911 Equalization Surcharge',
#     'amount': 0.06,
#     'category': 'Tax'},
#    {'description': 'City Sales Tax - Telecom',
#     'amount': 0.11,
#     'category': 'Tax'},
#    {'description': 'TX State Sales Tax - Telecom',
#     'amount': 0.41,
#     'category': 'Tax'}],
#   'total': 55.08},
#  {'name': 'POORNA CHANDRA',
#   'phone_number': '980.265.3508',
#   'items': [{'description': 'Smartphone trade-in promo 8 of 36',
#     'amount': -9.73,
#     'category': 'Usage'},
#    {'description': 'Upgrade promo 8 of 10',
#     'amount': -5.0,
#     'category': 'Usage'},
#    {'description': 'Unlimited Premium PL - 6+ Lines',
#     'amount': 40.99,
#     'category': 'Plan'},
#    {'description': 'AutoPay & paperless disc ($10 off w/ bank acct)',
#     'amount': None,
#     'category': 'Plan'},
#    {'description': 'Discount for bundled eligible wireless with internet',
#     'amount': -8.2,
#     'category': 'Plan'},
#    {'description': 'IPHONE 16 PRO M - Installment 8 of 36',
#     'amount': 38.89,
#     'category': 'Device'},
#    {'description': 'Administrative & Regulatory Cost Recovery Fee',
#     'amount': 3.49,
#     'category': 'Usage'},
#    {'description': 'Federal Universal Service Charge',
#     'amount': 0.54,
#     'category': 'Usage'},
#    {'description': 'TX State Cost Recovery Charge',
#     'amount': 0.13,
#     'category': 'Usage'},
#    {'description': 'Texas Universal Service',
#     'amount': 0.36,
#     'category': 'Usage'},
#    {'description': '9-1-1 Service Fee', 'amount': 0.5, 'category': 'Tax'},
#    {'description': '911 Equalization Surcharge',
#     'amount': 0.06,
#     'category': 'Tax'},
#    {'description': 'City Sales Tax - Telecom',
#     'amount': 0.09,
#     'category': 'Tax'},
#    {'description': 'TX State Sales Tax - Telecom',
#     'amount': 0.34,
#     'category': 'Tax'}],
#   'total': 62.46}]
